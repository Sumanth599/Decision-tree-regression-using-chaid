# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('/content/MELBOURNE_HOUSE_PRICES_LESS.xlsx')
df2 = pd.read_excel('/content/Melbourne_housing_FULL.xlsx')

# %%
df1.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#                   Date  Postcode             Regionname  Propertycount  \
# 0  2017-01-04 00:00:00      3067  Northern Metropolitan         4019.0
# 1  2017-01-04 00:00:00      3067  Northern Metropolitan         4019.0
# 2  2017-01-04 00:00:00      3067  Northern Metropolitan         4019.0
# 3  2017-01-04 00:00:00      3040   Western Metropolitan         1543.0
# 4  2017-01-04 00:00:00      3042   Western Metropolitan         3464.0
#
#    Distance                 CouncilArea
# 0       3.0          Yarra City Council
# 1       3.0          Yarra City Council
# 2       3.0          Yarra City Council
# 3       7.5  Moonee Valley City Council
# 4      10.4  Moonee Valley City Council

# %%
df1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
#        'CouncilArea'],
#       dtype='object')

# %%
df2.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#                   Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0  2016-03-09 00:00:00       2.5    3067.0  ...       1.0  1.0     126.0
# 1  2016-03-12 00:00:00       2.5    3067.0  ...       1.0  1.0     202.0
# 2  2016-04-02 00:00:00       2.5    3067.0  ...       1.0  0.0     156.0
# 3  2016-04-02 00:00:00       2.5    3067.0  ...       2.0  1.0       0.0
# 4  2017-04-03 00:00:00       2.5    3067.0  ...       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council  -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council  -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council  -37.8079    144.9934
# 3           NaN        NaN  Yarra City Council  -37.8114    145.0116
# 4         150.0     1900.0  Yarra City Council  -37.8093    144.9944
#
#               Regionname Propertycount
# 0  Northern Metropolitan        4019.0
# 1  Northern Metropolitan        4019.0
# 2  Northern Metropolitan           NaN
# 3  Northern Metropolitan        4019.0
# 4  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
df2.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df = pd.merge(df1,df2,how = 'outer')

# %%
df.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#                   Date  Postcode             Regionname  ...  Distance  \
# 0  2017-01-04 00:00:00    3067.0  Northern Metropolitan  ...       3.0
# 1  2017-01-04 00:00:00    3067.0  Northern Metropolitan  ...       3.0
# 2  2017-01-04 00:00:00    3067.0  Northern Metropolitan  ...       3.0
# 3  2017-01-04 00:00:00    3040.0   Western Metropolitan  ...       7.5
# 4  2017-01-04 00:00:00    3042.0   Western Metropolitan  ...      10.4
#
#                   CouncilArea Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0          Yarra City Council      NaN       NaN  NaN       NaN           NaN
# 1          Yarra City Council      NaN       NaN  NaN       NaN           NaN
# 2          Yarra City Council      NaN       NaN  NaN       NaN           NaN
# 3  Moonee Valley City Council      NaN       NaN  NaN       NaN           NaN
# 4  Moonee Valley City Council      NaN       NaN  NaN       NaN           NaN
#
#    YearBuilt  Lattitude  Longtitude
# 0        NaN        NaN         NaN
# 1        NaN        NaN         NaN
# 2        NaN        NaN         NaN
# 3        NaN        NaN         NaN
# 4        NaN        NaN         NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (76886, 21)

# %%
df.size
# Out:
# 1614606

# %%
df.describe()
# Out:
#               Rooms         Price      Postcode  Propertycount      Distance  \
# count  76886.000000  5.922800e+04  76885.000000   76872.000000  76885.000000
# mean       3.072887  1.012195e+06   3120.765936    7588.369784     11.966778
# std        0.966309  6.067010e+05    117.021312    4512.999749      7.203547
# min        1.000000  8.500000e+04   3000.000000      39.000000      0.000000
# 25%        2.000000  6.200000e+05   3054.000000    4380.000000      6.700000
# 50%        3.000000  8.450000e+05   3104.000000    6763.000000     10.800000
# 75%        4.000000  1.245000e+06   3163.000000   10412.000000     15.400000
# max       31.000000  1.120000e+07   3980.000000  173841.000000     64.100000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  26642.000000  26633.000000  26131.000000   23049.000000  13744.000000
# mean       3.084641      1.624901      1.728866     593.582628    160.265967
# std        0.980653      0.724283      1.010735    3398.694929    401.238645
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        2.000000      1.000000      1.000000     224.000000    102.000000
# 50%        3.000000      2.000000      2.000000     521.000000    136.000000
# 75%        4.000000      2.000000      2.000000     670.000000    188.000000
# max       30.000000     12.000000     26.000000  433014.000000  44515.000000
#
#           YearBuilt     Lattitude    Longtitude
# count  15553.000000  26883.000000  26883.000000
# mean    1965.294348    -37.810635    145.001863
# std       37.327853      0.090276      0.120173
# min     1196.000000    -38.190430    144.423790
# 25%     1940.000000    -37.862935    144.933500
# 50%     1970.000000    -37.807600    145.007800
# 75%     2000.000000    -37.754100    145.071905
# max     2106.000000    -37.390200    145.526350

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76886 entries, 0 to 76885
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         76886 non-null  object
#  1   Address        76886 non-null  object
#  2   Rooms          76886 non-null  int64
#  3   Type           76886 non-null  object
#  4   Price          59228 non-null  float64
#  5   Method         76886 non-null  object
#  6   SellerG        76883 non-null  object
#  7   Date           76886 non-null  object
#  8   Postcode       76885 non-null  float64
#  9   Regionname     76881 non-null  object
#  10  Propertycount  76872 non-null  float64
#  11  Distance       76885 non-null  float64
#  12  CouncilArea    76874 non-null  object
#  13  Bedroom2       26642 non-null  float64
#  14  Bathroom       26633 non-null  float64
#  15  Car            26131 non-null  float64
#  16  Landsize       23049 non-null  float64
#  17  BuildingArea   13744 non-null  float64
#  18  YearBuilt      15553 non-null  float64
#  19  Lattitude      26883 non-null  float64
#  20  Longtitude     26883 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 12.9+ MB

# %%
labels_dict = {}
cols_to_convert = ['Suburb','Address','Type','Method','SellerG','Date','Regionname','CouncilArea']  
for col in cols_to_convert:
    unique_values = df[col].unique()
    for i, val in enumerate(unique_values):
        labels_dict[val] = i
    df[col] = df[col].apply(lambda x: labels_dict[x])

# %%
labels_dict
# Out:
# {'Abbotsford': 0,
#  'Aberfeldie': 1,
#  'Airport West': 2,
#  'Albanvale': 3,
#  'Albert Park': 4,
#  'Albion': 5,
#  'Alphington': 6,
#  'Altona': 7,
#  'Altona Meadows': 8,
#  'Altona North': 9,
#  'Armadale': 10,
#  'Ascot Vale': 11,
#  'Ashburton': 12,
#  'Ashwood': 13,
#  'Aspendale': 14,
#  'Aspendale Gardens': 15,
#  'Attwood': 16,
#  'Avondale Heights': 17,
#  'Balwyn': 18,
#  'Balwyn North': 19,
#  'Bayswater North': 20,
#  'Beaumaris': 21,
#  'Bellfield': 22,
#  'Bentleigh': 23,
#  'Bentleigh East': 24,
#  'Black Rock': 25,
#  'Blackburn': 26,
#  'Blackburn North': 27,
#  'Blackburn South': 28,
#  'Bonbeach': 29,
#  'Boronia': 30,
#  'Box Hill': 31,
#  'Braybrook': 32,
#  'Brighton': 33,
#  'Brighton East': 34,
#  'Broadmeadows': 35,
#  'Brunswick': 36,
#  'Brunswick East': 37,
#  'Brunswick West': 38,
#  'Bulleen': 39,
#  'Bundoora': 40,
#  'Burwood': 41,
#  'Burwood East': 42,
#  'Camberwell': 43,
#  'Canterbury': 44,
#  'Carlton': 45,
#  'Carlton North': 46,
#  'Carnegie': 47,
#  'Caroline Springs': 48,
#  'Carrum': 49,
#  'Carrum Downs': 50,
#  'Caulfield East': 51,
#  'Caulfield North': 52,
#  'Caulfield South': 53,
#  'Chadstone': 54,
#  'Chelsea': 55,
#  'Cheltenham': 56,
#  'Chintin': 57,
#  'Clayton': 58,
#  'Clayton South': 59,
#  'Clifton Hill': 60,
#  'Coburg': 61,
#  'Coburg North': 62,
#  'Collingwood': 63,
#  'Craigieburn': 64,
#  'Cranbourne': 65,
#  'Cranbourne North': 66,
#  'Croydon': 67,
#  'Dallas': 68,
#  'Dandenong': 69,
#  'Dandenong North': 70,
#  'Darley': 71,
#  'Deepdene': 72,
#  'Deer Park': 73,
#  'Delahey': 74,
#  'Diamond Creek': 75,
#  'Dingley Village': 76,
#  'Doncaster': 77,
#  'Doncaster East': 78,
#  'Donvale': 79,
#  'Eaglemont': 80,
#  'East Melbourne': 81,
#  'Edithvale': 82,
#  'Elsternwick': 83,
#  'Eltham': 84,
#  'Eltham North': 85,
#  'Elwood': 86,
#  'Endeavour Hills': 87,
#  'Epping': 88,
#  'Essendon': 89,
#  'Essendon North': 90,
#  'Essendon West': 91,
#  'Fairfield': 92,
#  'Fawkner': 93,
#  'Ferntree Gully': 94,
#  'Fitzroy': 95,
#  'Fitzroy North': 96,
#  'Footscray': 97,
#  'Forest Hill': 98,
#  'Frankston': 99,
#  'Frankston North': 100,
#  'Frankston South': 101,
#  'Gladstone Park': 102,
#  'Glen Iris': 103,
#  'Glen Waverley': 104,
#  'Glenroy': 105,
#  'Gowanbrae': 106,
#  'Greensborough': 107,
#  'Greenvale': 108,
#  'Hadfield': 109,
#  'Hampton': 110,
#  'Hawthorn': 111,
#  'Heathmont': 112,
#  'Heidelberg': 113,
#  'Heidelberg Heights': 114,
#  'Heidelberg West': 115,
#  'Highett': 116,
#  'Hillside': 117,
#  'Hoppers Crossing': 118,
#  'Hughesdale': 119,
#  'Huntingdale': 120,
#  'Ivanhoe': 121,
#  'Ivanhoe East': 122,
#  'Jacana': 123,
#  'Keilor Downs': 124,
#  'Keilor East': 125,
#  'Kensington': 126,
#  'Kew': 127,
#  'Kew East': 128,
#  'Keysborough': 129,
#  'Kingsville': 130,
#  'Knoxfield': 131,
#  'Kurunjang': 132,
#  'Lalor': 133,
#  'Lilydale': 134,
#  'MacLeod': 135,
#  'Maidstone': 136,
#  'Malvern': 419,
#  'Malvern East': 138,
#  'Maribyrnong': 139,
#  'McKinnon': 140,
#  'Meadow Heights': 141,
#  'Melbourne': 112,
#  'Melton': 143,
#  'Mentone': 144,
#  'Mernda': 145,
#  'Middle Park': 146,
#  'Mill Park': 147,
#  'Mitcham': 148,
#  'Montmorency': 149,
#  'Moonee Ponds': 150,
#  'Moorabbin': 151,
#  'Mooroolbark': 152,
#  'Mordialloc': 153,
#  'Mount Waverley': 154,
#  'Mulgrave': 155,
#  'Murrumbeena': 156,
#  'Narre Warren': 157,
#  'Newport': 158,
#  'Noble Park': 159,
#  'North Melbourne': 160,
#  'Northcote': 161,
#  'Nunawading': 162,
#  'Oak Park': 163,
#  'Oakleigh': 164,
#  'Oakleigh South': 165,
#  'Ormond': 166,
#  'Pakenham': 167,
#  'Parkdale': 168,
#  'Parkville': 169,
#  'Pascoe Vale': 170,
#  'Patterson Lakes': 171,
#  'Plenty': 172,
#  'Point Cook': 173,
#  'Port Melbourne': 174,
#  'Prahran': 175,
#  'Preston': 176,
#  'Reservoir': 177,
#  'Richmond': 178,
#  'Riddells Creek': 179,
#  'Ringwood': 180,
#  'Ringwood East': 181,
#  'Ringwood North': 182,
#  'Rosanna': 183,
#  'Rowville': 184,
#  'Roxburgh Park': 185,
#  'Sandringham': 186,
#  'Scoresby': 187,
#  'Seaford': 188,
#  'Seddon': 189,
#  'South Melbourne': 190,
#  'South Morang': 191,
#  'South Yarra': 192,
#  'Southbank': 193,
#  'Spotswood': 194,
#  'Springvale': 195,
#  'St Albans': 196,
#  'St Kilda': 197,
#  'Strathmore': 198,
#  'Strathmore Heights': 199,
#  'Sunshine': 200,
#  'Sunshine North': 201,
#  'Sunshine West': 202,
#  'Surrey Hills': 203,
#  'Sydenham': 204,
#  'Taylors Lakes': 205,
#  'Templestowe': 206,
#  'Templestowe Lower': 207,
#  'Thomastown': 208,
#  'Thornbury': 209,
#  'Toorak': 210,
#  'Truganina': 211,
#  'Tullamarine': 212,
#  'Vermont South': 213,
#  'Wantirna': 214,
#  'Wantirna South': 215,
#  'Warrandyte': 216,
#  'Werribee': 217,
#  'West Footscray': 218,
#  'West Melbourne': 219,
#  'Westmeadows': 220,
#  'Wheelers Hill': 221,
#  'Williamstown': 222,
#  'Windsor': 223,
#  'Wollert': 224,
#  'Wyndham Vale': 225,
#  'Yarraville': 226,
#  'Ardeer': 227,
#  'Bayswater': 228,
#  'Berwick': 229,
#  'Briar Hill': 230,
#  'Brooklyn': 231,
#  'Burnside Heights': 232,
#  'Cairnlea': 233,
#  'Clarinda': 234,
#  'Clyde North': 235,
#  'Croydon Hills': 236,
#  'Croydon North': 237,
#  'Doreen': 238,
#  'Emerald': 239,
#  'Eumemmerring': 240,
#  'Gisborne': 241,
#  'Hallam': 242,
#  'Hampton East': 243,
#  'Healesville': 244,
#  'Keilor Lodge': 245,
#  'Kings Park': 246,
#  'Kingsbury': 247,
#  'Lower Plenty': 248,
#  'Lynbrook': 249,
#  'Melton South': 250,
#  'Melton West': 251,
#  'Mickleham': 252,
#  'Mont Albert': 253,
#  'Montrose': 254,
#  'Oakleigh East': 255,
#  'Princes Hill': 256,
#  'Rockbank': 257,
#  'Seabrook': 258,
#  'Seaholme': 259,
#  'Skye': 260,
#  'Springvale South': 261,
#  'St Helena': 262,
#  'Sunbury': 263,
#  'Tarneit': 264,
#  'Taylors Hill': 265,
#  'Tecoma': 266,
#  'The Basin': 267,
#  'Vermont': 268,
#  'Viewbank': 269,
#  'Werribee South': 270,
#  'Williams Landing': 271,
#  'Caulfield': 272,
#  'Croydon South': 273,
#  'Flemington': 274,
#  'Gardenvale': 275,
#  'Hawthorn East': 276,
#  'Kealba': 277,
#  'Keilor': 278,
#  'Keilor Park': 279,
#  'Niddrie': 280,
#  'Burnley': 281,
#  'Chirnside Park': 282,
#  'Cremorne': 283,
#  'Glen Huntly': 284,
#  'Hampton Park': 285,
#  'Manor Lakes': 286,
#  'North Warrandyte': 287,
#  'Plumpton': 288,
#  'South Kingsville': 289,
#  'Wallan': 290,
#  'Warranwood': 291,
#  'Watsonia': 292,
#  'Doveton': 293,
#  'Ferny Creek': 294,
#  'Balaclava': 295,
#  'Campbellfield': 296,
#  'Coolaroo': 297,
#  'Diggers Rest': 298,
#  'Heatherton': 299,
#  'Langwarrin': 300,
#  'Laverton': 301,
#  'Wandin North': 302,
#  'Watsonia North': 303,
#  'Yallambie': 304,
#  'Docklands': 305,
#  'Wattle Glen': 306,
#  'Kooyong': 307,
#  'Notting Hill': 308,
#  'Williamstown North': 309,
#  'Burnside': 310,
#  'Chelsea Heights': 311,
#  'Derrimut': 312,
#  'Kilsyth': 313,
#  'New Gisborne': 314,
#  'Ripponlea': 315,
#  'Pentland Hills': 316,
#  'Cranbourne East': 317,
#  'Eynesbury': 318,
#  'Gisborne South': 319,
#  'Oaklands Junction': 320,
#  'Sandhurst': 422,
#  'Research': 322,
#  'Travancore': 323,
#  'Upwey': 324,
#  'Waterways': 325,
#  'Yan Yean': 326,
#  'Cranbourne West': 327,
#  'Wonga Park': 328,
#  'Beaconsfield': 329,
#  'Botanic Ridge': 330,
#  'Gembrook': 331,
#  'Kilsyth South': 332,
#  'Woori Yallock': 333,
#  'Bacchus Marsh': 334,
#  'Macleod': 335,
#  'Panton Hill': 336,
#  'Lyndhurst': 337,
#  'Officer': 338,
#  'Mount Evelyn': 339,
#  'Kalkallo': 340,
#  'Warrandyte South': 341,
#  'Lysterfield': 342,
#  'Guys Hill': 343,
#  'Hurstbridge': 344,
#  'Whittlesea': 345,
#  'Monbulk': 346,
#  'Silvan': 347,
#  'Warburton': 348,
#  'Cockatoo': 349,
#  'Kallista': 350,
#  'Bullengarook': 351,
#  'Brookfield': 352,
#  'Bulla': 353,
#  'Seville': 354,
#  'Olinda': 355,
#  'Avonsleigh': 356,
#  'Wildwood': 357,
#  'Castella': 358,
#  'Park Orchards': 359,
#  'Kalorama': 360,
#  'Belgrave': 361,
#  'Beaconsfield Upper': 362,
#  'Coldstream': 363,
#  'Hopetoun Park': 364,
#  'Toolern Vale': 365,
#  'Belgrave South': 366,
#  'Don Valley': 367,
#  'Yarra Glen': 368,
#  'Mount Dandenong': 369,
#  'Menzies Creek': 370,
#  'Cranbourne South': 371,
#  'Warneet': 372,
#  'croydon': 373,
#  'Belgrave Heights': 374,
#  'Yarrambat': 375,
#  'viewbank': 376,
#  'Maddingley': 377,
#  'Yarra Junction': 378,
#  'Lysterfield South': 379,
#  'Fawkner Lot': 380,
#  '49 Lithgow St': 0,
#  '59A Turner St': 1,
#  '119B Yarra St': 2,
#  '68 Vida St': 3,
#  '92 Clydesdale Rd': 4,
#  '4/32 Earl St': 5,
#  '3/74 Hawker St': 6,
#  '1/26 Highridge Cr': 7,
#  '1 Jackson Cct': 8,
#  '18 Mills St': 9,
#  '3/15 Drummartin St': 10,
#  '3A Kororoit St': 11,
#  '55 Fulham Rd': 12,
#  '41 Toolangi Rd': 13,
#  '9 Delmont Av': 14,
#  '57 Tatman Dr': 15,
#  '14 Seventh Av': 16,
#  '2/23 Ashleigh Rd': 17,
#  '6A Auburn Gr': 18,
#  '746 High St': 19,
#  '14/25 Kooyong Rd': 20,
#  '6/38 Wattletree Rd': 21,
#  '8 The Grove': 22,
#  '1/48 Karnak Rd': 23,
#  '1 Pitt St': 24,
#  '61A Victory Bvd': 25,
#  '43 Douglas St': 26,
#  '4 Jirrah Ct': 27,
#  '8 Mangrove Ct': 28,
#  '46 Threadneedle St': 29,
#  '12 Duke St': 30,
#  '104/29 Belgrove Av': 31,
#  '2/362 Belmore Rd': 32,
#  '9 Kenilworth St': 33,
#  '4 Lynch Ct': 34,
#  '4/40 Northcote Av': 35,
#  '306 Union Rd': 36,
#  '3 Abbott St': 37,
#  '12 Agnes Av': 38,
#  '203 Belmore Rd': 39,
#  '56 Clifton St': 40,
#  '9 Cumberland Av': 41,
#  '1 Kalka St': 42,
#  '2/4 Maylands Av': 43,
#  '8 Wattle Rd': 44,
#  '500 Balcombe Rd': 45,
#  '2/58 Haydens Rd': 46,
#  '6 haywood St': 47,
#  '2/3 Hutchison Av': 48,
#  '39 White St': 49,
#  '1/15 Toohey St': 50,
#  '4b Hobart St': 51,
#  '36a Marquis Rd': 52,
#  '5 Mortimore St': 53,
#  '2 Smith St': 54,
#  '40 Castlewood St': 55,
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         76886 non-null  int64
#  1   Address        76886 non-null  int64
#  2   Rooms          76886 non-null  int64
#  3   Type           76886 non-null  int64
#  4   Price          59228 non-null  float64
#  5   Method         76886 non-null  int64
#  6   SellerG        76886 non-null  int64
#  7   Date           76886 non-null  int64
#  8   Postcode       76885 non-null  float64
#  9   Regionname     76886 non-null  int64
#  10  Propertycount  76872 non-null  float64
#  11  Distance       76885 non-null  float64
#  12  CouncilArea    76886 non-null  int64
#  13  Bedroom2       26642 non-null  float64
#  14  Bathroom       26633 non-null  float64
#  15  Car            26131 non-null  float64
#  16  Landsize       23049 non-null  float64
#  17  BuildingArea   13744 non-null  float64
#  18  YearBuilt      15553 non-null  float64
#  19  Lattitude      26883 non-null  float64
#  20  Longtitude     26883 non-null  float64
# dtypes: float64(12), int64(9)
# memory usage: 12.9 MB

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price            17658
# Method               0
# SellerG              0
# Date                 0
# Postcode             1
# Regionname           0
# Propertycount       14
# Distance             1
# CouncilArea          0
# Bedroom2         50244
# Bathroom         50253
# Car              50755
# Landsize         53837
# BuildingArea     63142
# YearBuilt        61333
# Lattitude        50003
# Longtitude       50003
# dtype: int64

# %%
df['Price']=df['Price'].fillna(df['Price']).median()
df['Postcode']=df['Postcode'].fillna(df['Postcode']).median()
df['Propertycount']=df['Propertycount'].fillna(df['Propertycount']).median()
df['Distance']=df['Distance'].fillna(df['Distance']).median()
df['Bedroom2']=df['Bedroom2'].fillna(df['Bedroom2']).median()
df['Bathroom']=df['Bathroom'].fillna(df['Bathroom']).median()
df['Car']=df['Car'].fillna(df['Car']).median()
df['Landsize']=df['Landsize'].fillna(df['Landsize']).median()
df['BuildingArea']=df['BuildingArea'].fillna(df['BuildingArea']).median()
df['YearBuilt']=df['YearBuilt'].fillna(df['YearBuilt']).median()
df['Lattitude']=df['Lattitude'].fillna(df['Lattitude']).median()
df['Longtitude']=df['Longtitude'].fillna(df['Longtitude']).median()

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Postcode         0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Lattitude        0
# Longtitude       0
# dtype: int64

# %%
train = df.sample(frac=0.8,random_state=123)
test = df.drop(train.index)

# %%
# split the data into train and test sets
X_train = train.drop(['Price'],axis=1)
y_train = train['Price']
X_test = test.drop(['Price'],axis=1)
y_test = test['Price']

# %%
X_train
# Out:
#        Suburb  Address  Rooms  Type  Method  SellerG  Date  Postcode  \
# 18853     111    17878      2     2       4        4    35    3104.0
# 11449     156    11379      4     0       3       11    21    3104.0
# 63114       2    18172      3     1       2        3    36    3104.0
# 67544     105    32108      4     1       0       51    63    3104.0
# 36507     122    34186      2     2       0       15    66    3104.0
# ...       ...      ...    ...   ...     ...      ...   ...       ...
# 40497     116    38012      4     0       1        1    73    3104.0
# 3959       24     3950      4     1       0        4     7    3104.0
# 75751     127     9402      5     0       0       26    17    3104.0
# 36061     174    33751      2     0       0        5    65    3104.0
# 35223     147    32942      4     0       0       60    64    3104.0
#
#        Regionname  Propertycount  Distance  CouncilArea  Bedroom2  Bathroom  \
# 18853           2         6763.0      10.8            7       3.0       2.0
# 11449           2         6763.0      10.8           14       3.0       2.0
# 63114           1         6763.0      10.8            1       3.0       2.0
# 67544           0         6763.0      10.8           18       3.0       2.0
# 36507           4         6763.0      10.8           13       3.0       2.0
# ...           ...            ...       ...          ...       ...       ...
# 40497           2         6763.0      10.8           12       3.0       2.0
# 3959            2         6763.0      10.8           14       3.0       2.0
# 75751           2         6763.0      10.8            7       3.0       2.0
# 36061           2         6763.0      10.8           20       3.0       2.0
# 35223           0         6763.0      10.8           28       3.0       2.0
#
#        Car  Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude
# 18853  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 11449  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 63114  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 67544  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 36507  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# ...    ...       ...           ...        ...        ...         ...
# 40497  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 3959   2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 75751  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 36061  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 35223  2.0     521.0         136.0     1970.0   -37.8076    145.0078
#
# [61509 rows x 20 columns]

# %%
X_test
# Out:
#        Suburb  Address  Rooms  Type  Method  SellerG  Date  Postcode  \
# 0           0        0      3     0       0        0     0    3104.0
# 2           0        2      3     0       0        2     0    3104.0
# 4           2        4      2     0       0        2     0    3104.0
# 6           2        6      2     2       0        3     0    3104.0
# 7           2        7      3     0       1        2     0    3104.0
# ...       ...      ...    ...   ...     ...      ...   ...       ...
# 76869     219    23244      3     0       0       18    45    3104.0
# 76873     219    37769      1     2       2       60    72    3104.0
# 76875     219    56393      1     2       1       88   105    3104.0
# 76880     259    39584      2     2       2        4    76    3104.0
# 76883      97    26222      2     2       0       25    52    3104.0
#
#        Regionname  Propertycount  Distance  CouncilArea  Bedroom2  Bathroom  \
# 0               0         6763.0      10.8            0       3.0       2.0
# 2               0         6763.0      10.8            0       3.0       2.0
# 4               1         6763.0      10.8            1       3.0       2.0
# 6               1         6763.0      10.8            1       3.0       2.0
# 7               1         6763.0      10.8            1       3.0       2.0
# ...           ...            ...       ...          ...       ...       ...
# 76869           0         6763.0      10.8           20       3.0       2.0
# 76873           0         6763.0      10.8           20       3.0       2.0
# 76875           0         6763.0      10.8           20       3.0       2.0
# 76880           1         6763.0      10.8            5       3.0       2.0
# 76883           8         6763.0      10.8           32       3.0       2.0
#
#        Car  Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude
# 0      2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 2      2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 4      2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 6      2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 7      2.0     521.0         136.0     1970.0   -37.8076    145.0078
# ...    ...       ...           ...        ...        ...         ...
# 76869  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 76873  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 76875  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 76880  2.0     521.0         136.0     1970.0   -37.8076    145.0078
# 76883  2.0     521.0         136.0     1970.0   -37.8076    145.0078
#
# [15377 rows x 20 columns]

# %%
def calc_std_reduction(y, y_left, y_right):
    std_parent = np.std(y)
    std_left = np.std(y_left)
    std_right = np.std(y_right)
    n_total = len(y)
    n_left = len(y_left)
    n_right = len(y_right)
    std_reduction = std_parent - ((n_left/n_total)*std_left + (n_right/n_total)*std_right)
    return std_reduction

def best_split(X, y, min_samples_split):
    best_feature_idx, best_feature_val, best_std_reduction = None, None, 0
    n_features = X.shape[1]
    for feature_idx in range(n_features):
        feature_vals = np.unique(X[:, feature_idx])
        for feature_val in feature_vals:
            y_left = y[X[:, feature_idx] <= feature_val]
            y_right = y[X[:, feature_idx] > feature_val]
            if len(y_left) >= min_samples_split and len(y_right) >= min_samples_split:
                std_reduction = calc_std_reduction(y, y_left, y_right)
                if std_reduction > best_std_reduction:
                    best_feature_idx = feature_idx
                    best_feature_val = feature_val
                    best_std_reduction = std_reduction

    return best_feature_idx, best_feature_val

def build_tree(X, y, max_depth, min_samples_split, depth=0):
    n_samples, n_features = X.shape

    if depth == max_depth or n_samples < min_samples_split or len(np.unique(y)) == 1:
        leaf_value = np.mean(y)
        return leaf_value

    split_idx, split_val = best_split(X, y, min_samples_split)

    if split_idx is None:
        leaf_value = np.mean(y)
        return leaf_value

    left_idx = X[:, split_idx] <= split_val
    right_idx = X[:, split_idx] > split_val

    if sum(left_idx) == 0 or sum(right_idx) == 0:
        leaf_value = np.mean(y)
        return leaf_value

    tree = {}
    tree['split_idx'] = split_idx
    tree['split_val'] = split_val
    tree['left'] = build_tree(X[left_idx], y[left_idx], max_depth, min_samples_split, depth+1)
    tree['right'] = build_tree(X[right_idx], y[right_idx], max_depth, min_samples_split, depth+1)

    return tree

def fit(X, y, max_depth=None, min_samples_split=2):
    tree = build_tree(X, y, max_depth, min_samples_split, depth=0)
    return tree

def predict(X, tree):
    n_samples = X.shape[0]
    y_pred = np.zeros(n_samples)
    for i in range(n_samples):
        y_pred[i] = predict_tree(X[i], tree)
    return y_pred

def predict_tree(x, tree):
    if isinstance(tree, np.float64):
        return tree
    feature_val = x[tree['split_idx']]
    if feature_val <= tree['split_val']:
        return predict_tree(x, tree['left'])
    else:
        return predict_tree(x, tree['right'])

# %%
def grid_search(X_train, y_train, X_test, y_test, max_depth_options, min_samples_split_options):
    best_score = float('-inf')
    best_params = {}
    for max_depth in max_depth_options:
        for min_samples_split in min_samples_split_options:
            model = fit(X_train, y_train, max_depth=max_depth, min_samples_split=min_samples_split)
            y_pred = predict(X_test, model)
            score = r2_score(y_test, y_pred) # or any other evaluation metric
            if score > best_score:
                best_score = score
                best_params['max_depth'] = max_depth
                best_params['min_samples_split'] = min_samples_split
    return best_params

# %%
def r2_score(y_true, y_pred):
    ss_total = np.sum((y_true - np.mean(y_true))**2)
    if ss_total == 0:
        return 0
    ss_res = np.sum((y_true - y_pred)**2)
    r2 = 1 - (ss_res / ss_total)
    return r2

# %%
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 4, 6, 8, 10]
}

# %%
grid_search(X_train.values, y_train.values, X_test.values, y_test.values, param_grid['max_depth'], param_grid['min_samples_split'])
# Out:
# {'max_depth': 2, 'min_samples_split': 2}

# %%
tree = build_tree(X_train.values, y_train.values, max_depth=2, min_samples_split=2, depth=0)

# %%
y_pred = predict(X_test.values, tree)

# %%
y_pred
# Out:
# array([845000., 845000., 845000., ..., 845000., 845000., 845000.])

# %%
r2_score(y_test, y_pred)
# Out:
# 0
